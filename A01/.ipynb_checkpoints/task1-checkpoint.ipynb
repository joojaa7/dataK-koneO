# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
chronic_kidney_disease = fetch_ucirepo(id=336) 
  
# data (as pandas dataframes) 
X = chronic_kidney_disease.data.features 
y = chronic_kidney_disease.data.targets 
  
# metadata 
  
# variable information 
df = pd.concat([X, y], axis=1)
df
# Out:
#       age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0    48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1     7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2    62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3    48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4    51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...     ...       ...         ...         ...
# 395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
#        bgr  ...   pcv    wbcc  rbcc  htn   dm  cad  appet   pe  ane   class
# 0    121.0  ...  44.0  7800.0   5.2  yes  yes   no   good   no   no     ckd
# 1      NaN  ...  38.0  6000.0   NaN   no   no   no   good   no   no     ckd
# 2    423.0  ...  31.0  7500.0   NaN   no  yes   no   poor   no  yes     ckd
# 3    117.0  ...  32.0  6700.0   3.9  yes   no   no   poor  yes  yes     ckd
# 4    106.0  ...  35.0  7300.0   4.6   no   no   no   good   no   no     ckd
# ..     ...  ...   ...     ...   ...  ...  ...  ...    ...  ...  ...     ...
# 395  140.0  ...  47.0  6700.0   4.9   no   no   no   good   no   no  notckd
# 396   75.0  ...  54.0  7800.0   6.2   no   no   no   good   no   no  notckd
# 397  100.0  ...  49.0  6600.0   5.4   no   no   no   good   no   no  notckd
# 398  114.0  ...  51.0  7200.0   5.9   no   no   no   good   no   no  notckd
# 399  131.0  ...  53.0  6800.0   6.1   no   no   no   good   no   no  notckd
#
# [400 rows x 25 columns]

# %%
df["hemo"] = df["hemo"]/10

# %%
df.hemo
# Out:
# 0      1.54
# 1      1.13
# 2      0.96
# 3      1.12
# 4      1.16
#        ...
# 395    1.57
# 396    1.65
# 397    1.58
# 398    1.42
# 399    1.58
# Name: hemo, Length: 400, dtype: float64

# %%
df['class'] = df['class'].replace({'ckd': 'a','ckd\t': "a", 'notckd': 'c'})

# %%
df["class"].unique()
# Out:
# array(['a', 'c'], dtype=object)

# %%
df.describe(include='all')
# Out:
#                age          bp          sg          al          su     rbc  \
# count   391.000000  388.000000  353.000000  354.000000  351.000000     248
# unique         NaN         NaN         NaN         NaN         NaN       2
# top            NaN         NaN         NaN         NaN         NaN  normal
# freq           NaN         NaN         NaN         NaN         NaN     201
# mean     51.483376   76.469072    1.017408    1.016949    0.450142     NaN
# std      17.169714   13.683637    0.005717    1.352679    1.099191     NaN
# min       2.000000   50.000000    1.005000    0.000000    0.000000     NaN
# 25%      42.000000   70.000000    1.010000    0.000000    0.000000     NaN
# 50%      55.000000   80.000000    1.020000    0.000000    0.000000     NaN
# 75%      64.500000   80.000000    1.020000    2.000000    0.000000     NaN
# max      90.000000  180.000000    1.025000    5.000000    5.000000     NaN
#
#             pc         pcc          ba         bgr  ...         pcv  \
# count      335         396         396  356.000000  ...  329.000000
# unique       2           2           2         NaN  ...         NaN
# top     normal  notpresent  notpresent         NaN  ...         NaN
# freq       259         354         374         NaN  ...         NaN
# mean       NaN         NaN         NaN  148.036517  ...   38.884498
# std        NaN         NaN         NaN   79.281714  ...    8.990105
# min        NaN         NaN         NaN   22.000000  ...    9.000000
# 25%        NaN         NaN         NaN   99.000000  ...   32.000000
# 50%        NaN         NaN         NaN  121.000000  ...   40.000000
# 75%        NaN         NaN         NaN  163.000000  ...   45.000000
# max        NaN         NaN         NaN  490.000000  ...   54.000000
#
#                 wbcc        rbcc  htn   dm  cad  appet   pe  ane class
# count     294.000000  269.000000  398  398  398    399  399  399   400
# unique           NaN         NaN    2    3    2      2    2    2     2
# top              NaN         NaN   no   no   no   good   no   no     a
# freq             NaN         NaN  251  260  364    317  323  339   250
# mean     8406.122449    4.707435  NaN  NaN  NaN    NaN  NaN  NaN   NaN
# std      2944.474190    1.025323  NaN  NaN  NaN    NaN  NaN  NaN   NaN
# min      2200.000000    2.100000  NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 25%      6500.000000    3.900000  NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 50%      8000.000000    4.800000  NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 75%      9800.000000    5.400000  NaN  NaN  NaN    NaN  NaN  NaN   NaN
# max     26400.000000    8.000000  NaN  NaN  NaN    NaN  NaN  NaN   NaN
#
# [11 rows x 25 columns]

# %%
threshold = len(df.columns)-3
df.dropna(thresh=threshold,inplace=True)
print(len(df))
# Out:
# 273

# %%
df1 = df[df["class"]=="a"]
df2 = df[df["class"]=="c"]
print(len(df1))
print(len(df2))
# Out:
# 133
# 140

# %%
df1
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 0    48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 2    62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent
# 3    48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 4    51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 5    60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent  notpresent
# ..    ...    ...    ...  ...  ...       ...       ...         ...         ...
# 243  62.0   90.0  1.020  2.0  1.0       NaN    normal  notpresent  notpresent
# 244  64.0   90.0  1.015  3.0  2.0       NaN  abnormal     present  notpresent
# 246  48.0  110.0  1.015  3.0  0.0  abnormal    normal     present  notpresent
# 248  59.0   70.0  1.010  1.0  3.0  abnormal  abnormal  notpresent  notpresent
# 249  56.0   90.0  1.010  4.0  1.0    normal  abnormal     present  notpresent
#
#        bgr  ...   pcv     wbcc  rbcc  htn   dm  cad  appet   pe  ane class
# 0    121.0  ...  44.0   7800.0   5.2  yes  yes   no   good   no   no     a
# 2    423.0  ...  31.0   7500.0   NaN   no  yes   no   poor   no  yes     a
# 3    117.0  ...  32.0   6700.0   3.9  yes   no   no   poor  yes  yes     a
# 4    106.0  ...  35.0   7300.0   4.6   no   no   no   good   no   no     a
# 5     74.0  ...  39.0   7800.0   4.4  yes  yes   no   good  yes   no     a
# ..     ...  ...   ...      ...   ...  ...  ...  ...    ...  ...  ...   ...
# 243  169.0  ...  47.0  11000.0   6.1  yes   no   no   good   no   no     a
# 244  463.0  ...  40.0   9800.0   4.6  yes  yes   no   good   no  yes     a
# 246  106.0  ...  26.0   5000.0   2.5  yes   no  yes   good   no  yes     a
# 248  424.0  ...  37.0  10200.0   4.1  yes  yes  yes   good   no   no     a
# 249  176.0  ...   9.0   5400.0   2.1  yes  yes   no   poor  yes  yes     a
#
# [133 rows x 25 columns]

# %%
df2
# Out:
#       age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 250  40.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 251  23.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 252  45.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 253  57.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 254  51.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...     ...     ...         ...         ...
# 395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#        bgr  ...   pcv     wbcc  rbcc  htn  dm  cad  appet  pe ane class
# 250  140.0  ...  48.0  10400.0   4.5   no  no   no   good  no  no     c
# 251   70.0  ...  52.0   9800.0   5.0   no  no   no   good  no  no     c
# 252   82.0  ...  46.0   9100.0   4.7   no  no   no   good  no  no     c
# 253  119.0  ...  42.0   6200.0   6.2   no  no   no   good  no  no     c
# 254   99.0  ...  49.0   8300.0   5.2   no  no   no   good  no  no     c
# ..     ...  ...   ...      ...   ...  ...  ..  ...    ...  ..  ..   ...
# 395  140.0  ...  47.0   6700.0   4.9   no  no   no   good  no  no     c
# 396   75.0  ...  54.0   7800.0   6.2   no  no   no   good  no  no     c
# 397  100.0  ...  49.0   6600.0   5.4   no  no   no   good  no  no     c
# 398  114.0  ...  51.0   7200.0   5.9   no  no   no   good  no  no     c
# 399  131.0  ...  53.0   6800.0   6.1   no  no   no   good  no  no     c
#
# [140 rows x 25 columns]

# %%
df1.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  130.000000  131.000000  132.000000  133.000000  133.000000  126.000000
# mean    56.223077   80.458015    1.013712    1.857143    0.789474  182.912698
# std     15.288069   15.780348    0.004649    1.414979    1.331737   96.482871
# min      6.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     48.000000   70.000000    1.010000    1.000000    0.000000  107.250000
# 50%     60.000000   80.000000    1.015000    2.000000    0.000000  158.000000
# 75%     65.000000   90.000000    1.015000    3.000000    1.000000  240.500000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo         pcv  \
# count  132.000000  133.000000  110.000000  110.000000  131.000000  130.000000
# mean    78.281061    4.266917  133.736364    4.740000    1.065420   32.715385
# std     59.877941    4.255971    7.615384    4.165855    0.221805    7.217802
# min      1.500000    0.600000  104.000000    2.500000    0.310000    9.000000
# 25%     36.000000    1.600000  131.250000    3.825000    0.955000   29.000000
# 50%     57.500000    2.600000  136.000000    4.200000    1.090000   33.000000
# 75%    100.450000    5.300000  139.000000    4.900000    1.200000   37.000000
# max    322.000000   24.000000  145.000000   47.000000    1.610000   52.000000
#
#                wbcc        rbcc
# count    119.000000  109.000000
# mean    9252.100840    3.990826
# std     3757.858404    0.851528
# min     2200.000000    2.100000
# 25%     6900.000000    3.400000
# 50%     9200.000000    3.900000
# 75%    10800.000000    4.400000
# max    26400.000000    8.000000

# %%
df2.describe()
# Out:
#               age          bp          sg     al     su         bgr  \
# count  140.000000  138.000000  139.000000  139.0  139.0  136.000000
# mean    46.392857   71.304348    1.022482    0.0    0.0  107.830882
# std     15.877542    8.613865    0.002509    0.0    0.0   18.587353
# min     12.000000   60.000000    1.020000    0.0    0.0   70.000000
# 25%     34.000000   60.000000    1.020000    0.0    0.0   93.750000
# 50%     46.000000   70.000000    1.020000    0.0    0.0  108.500000
# 75%     58.000000   80.000000    1.025000    0.0    0.0  124.000000
# max     80.000000   80.000000    1.025000    0.0    0.0  140.000000
#
#                bu          sc         sod         pot        hemo         pcv  \
# count  136.000000  137.000000  137.000000  137.000000  137.000000  139.000000
# mean    32.963235    0.871533  141.649635    4.338686    1.519343   46.215827
# std     11.453227    0.258089    4.795205    0.591017    0.128436    4.108603
# min     10.000000    0.400000  135.000000    3.300000    1.300000   40.000000
# 25%     23.750000    0.600000  138.000000    3.700000    1.410000   43.000000
# 50%     33.000000    0.900000  141.000000    4.500000    1.500000   46.000000
# 75%     44.000000    1.100000  145.000000    4.900000    1.620000   50.000000
# max     50.000000    1.200000  150.000000    5.000000    1.780000   54.000000
#
#                wbcc        rbcc
# count    136.000000  136.000000
# mean    7677.941176    5.380147
# std     1837.497944    0.592399
# min     4300.000000    4.500000
# 25%     6300.000000    4.900000
# 50%     7400.000000    5.300000
# 75%     9225.000000    5.900000
# max    11000.000000    6.500000

# %%
import matplotlib.pyplot as plt

def plot_data(df):
    plt.figure(figsize=(30, 20))
    rows = len(df)
    for i, col in enumerate(df.select_dtypes(include=['int', 'float'])):
        plt.subplot(5, 3, i + 1)
        df[col].plot(kind='hist', title=col)
        plt.xlabel(col)
        plt.tight_layout()

# %%
plot_data(df1)

# %%
plot_data(df2)

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].astype('category')

# %%
corr1 = df1.corr(numeric_only=True)
corr2 = df2.corr(numeric_only=True)

# %%
corr1
# Out:
#            age        bp        sg        al        su       bgr        bu  \
# age   1.000000  0.086664 -0.079442 -0.006430  0.112846  0.179386  0.077848
# bp    0.086664  1.000000  0.024847  0.002680  0.194872  0.054560  0.081921
# sg   -0.079442  0.024847  1.000000 -0.037117 -0.069014 -0.119856 -0.050668
# al   -0.006430  0.002680 -0.037117  1.000000  0.152771  0.098449  0.414672
# su    0.112846  0.194872 -0.069014  0.152771  1.000000  0.726782 -0.029595
# bgr   0.179386  0.054560 -0.119856  0.098449  0.726782  1.000000 -0.032135
# bu    0.077848  0.081921 -0.050668  0.414672 -0.029595 -0.032135  1.000000
# sc    0.035445  0.083817 -0.122730  0.318110  0.002638 -0.107609  0.715390
# sod  -0.031527  0.155145  0.151860 -0.178871  0.055215 -0.054246 -0.311291
# pot  -0.009744  0.068268  0.044015  0.176782  0.152229  0.019830  0.197388
# hemo -0.088728 -0.096554  0.097115 -0.365026  0.134516  0.119641 -0.607012
# pcv  -0.132125 -0.106699  0.133177 -0.323936  0.097217  0.093242 -0.580311
# wbcc  0.087738 -0.026615 -0.063772  0.085126  0.112277  0.042777 -0.084173
# rbcc -0.064228  0.110443  0.109812 -0.235476  0.085110  0.158261 -0.494902
#
#             sc       sod       pot      hemo       pcv      wbcc      rbcc
# age   0.035445 -0.031527 -0.009744 -0.088728 -0.132125  0.087738 -0.064228
# bp    0.083817  0.155145  0.068268 -0.096554 -0.106699 -0.026615  0.110443
# sg   -0.122730  0.151860  0.044015  0.097115  0.133177 -0.063772  0.109812
# al    0.318110 -0.178871  0.176782 -0.365026 -0.323936  0.085126 -0.235476
# su    0.002638  0.055215  0.152229  0.134516  0.097217  0.112277  0.085110
# bgr  -0.107609 -0.054246  0.019830  0.119641  0.093242  0.042777  0.158261
# bu    0.715390 -0.311291  0.197388 -0.607012 -0.580311 -0.084173 -0.494902
# sc    1.000000 -0.393686  0.081774 -0.464924 -0.461539 -0.119216 -0.474844
# sod  -0.393686  1.000000  0.002244  0.278025  0.317933  0.019813  0.266934
# pot   0.081774  0.002244  1.000000 -0.173332 -0.198267 -0.169043 -0.185432
# hemo -0.464924  0.278025 -0.173332  1.000000  0.949188  0.022575  0.783870
# pcv  -0.461539  0.317933 -0.198267  0.949188  1.000000 -0.035372  0.801178
# wbcc -0.119216  0.019813 -0.169043  0.022575 -0.035372  1.000000  0.028162
# rbcc -0.474844  0.266934 -0.185432  0.783870  0.801178  0.028162  1.000000

# %%
corr2
# Out:
#            age        bp        sg  al  su       bgr        bu        sc  \
# age   1.000000 -0.063227 -0.087911 NaN NaN  0.099696  0.075513  0.015549
# bp   -0.063227  1.000000  0.075572 NaN NaN -0.007611 -0.091255  0.074481
# sg   -0.087911  0.075572  1.000000 NaN NaN -0.053700 -0.052684  0.012613
# al         NaN       NaN       NaN NaN NaN       NaN       NaN       NaN
# su         NaN       NaN       NaN NaN NaN       NaN       NaN       NaN
# bgr   0.099696 -0.007611 -0.053700 NaN NaN  1.000000 -0.067352  0.140140
# bu    0.075513 -0.091255 -0.052684 NaN NaN -0.067352  1.000000 -0.104725
# sc    0.015549  0.074481  0.012613 NaN NaN  0.140140 -0.104725  1.000000
# sod   0.109851 -0.114026 -0.016868 NaN NaN -0.001492  0.008259 -0.071599
# pot  -0.089180 -0.072518  0.069673 NaN NaN  0.129764  0.043917  0.012657
# hemo  0.055705  0.154155  0.024154 NaN NaN -0.150338  0.085826  0.073132
# pcv  -0.021698 -0.027320  0.010660 NaN NaN -0.230558  0.128584 -0.035044
# wbcc  0.137629 -0.078297 -0.025328 NaN NaN -0.081011  0.031877 -0.012574
# rbcc -0.052581 -0.036339  0.074202 NaN NaN -0.179728 -0.004224  0.160646
#
#            sod       pot      hemo       pcv      wbcc      rbcc
# age   0.109851 -0.089180  0.055705 -0.021698  0.137629 -0.052581
# bp   -0.114026 -0.072518  0.154155 -0.027320 -0.078297 -0.036339
# sg   -0.016868  0.069673  0.024154  0.010660 -0.025328  0.074202
# al         NaN       NaN       NaN       NaN       NaN       NaN
# su         NaN       NaN       NaN       NaN       NaN       NaN
# bgr  -0.001492  0.129764 -0.150338 -0.230558 -0.081011 -0.179728
# bu    0.008259  0.043917  0.085826  0.128584  0.031877 -0.004224
# sc   -0.071599  0.012657  0.073132 -0.035044 -0.012574  0.160646
# sod   1.000000  0.082653 -0.009461 -0.001598  0.334727 -0.099694
# pot   0.082653  1.000000  0.097159 -0.147301  0.043702 -0.043354
# hemo -0.009461  0.097159  1.000000  0.062829 -0.190950  0.079470
# pcv  -0.001598 -0.147301  0.062829  1.000000 -0.107374  0.040987
# wbcc  0.334727  0.043702 -0.190950 -0.107374  1.000000 -0.062058
# rbcc -0.099694 -0.043354  0.079470  0.040987 -0.062058  1.000000

# %%
def create_heatmap(corr):
    plt.figure(figsize=(10, 10))
    plt.imshow(corr, cmap='coolwarm', interpolation='none')
    plt.colorbar()
    plt.xticks(range(len(corr)), corr.columns, rotation=90)
    plt.yticks(range(len(corr)), corr.columns)
    plt.show()

# %%
create_heatmap(corr1)

# %%
create_heatmap(corr2)
